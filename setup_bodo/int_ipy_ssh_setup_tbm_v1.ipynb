# %%
# %sh
#!/usr/bin/env bash
rm -f "/root/.ssh/id_rsa"
ssh-keygen -t rsa -N "" -f "/root/.ssh/id_rsa"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Generating public/private rsa key pair.
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:kVYewVQYcmV5Z3jbprx+NXAH0JIWRfgHW2rcZL+n5Og root@1014-162708-fujf0q9l-10-44-235-163
# The key&#39;s randomart image is:
# +---[RSA 2048]----+
#         .oB**Xo. |
#          *oo* * B|
#         + .. = &amp;+|
#        . .   .*oB|
#         S    oo+o|
#               +oo|
#              + o+|
#             . + .|
#            .E... |
# +----[SHA256]-----+
# </div>

# %%
# %sh
#!/usr/bin/env bash
rm -f "/home/ubuntu/.ssh/id_rsa"
ssh-keygen -t rsa -N "" -f "/home/ubuntu/.ssh/id_rsa"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Generating public/private rsa key pair.
# Your identification has been saved in /home/ubuntu/.ssh/id_rsa.
# Your public key has been saved in /home/ubuntu/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:WPDfiRji1pNKzzanf5rxPn5AdX25EsdZGnFzuSoWbSM root@1014-162708-fujf0q9l-10-44-235-163
# The key&#39;s randomart image is:
# +---[RSA 2048]----+
#       .       +oX|
#        o     ..X*|
#       . +   ..+.+|
#      . = = E.* o |
#       = S o.* +  |
#      o + . o..   |
#       . = + ..   |
#        . + +o .  |
#         ..+=+o   |
# +----[SHA256]-----+
# </div>

# %%
# %sh
sudo service ssh start
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"> * Starting OpenBSD Secure Shell server sshd
#    ...done.
# </div>
